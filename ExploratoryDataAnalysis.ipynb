# %%
#import libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACESH.csv")
# Out:
# /var/folders/cp/64j87vx54fv6vr30wbh6p31r0000gn/T/ipykernel_326/1709224269.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACESH.csv")

# %%
#See the data that's been imported

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
#Clean up data

# %%
#Only want USA Races, 50k or 50mu, 2020

# %%
#Step 1 Show 50k or 50mi
#50km
#50mi

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Combine 50k/50mi with isin

# %%
df[df['Event distance/length'].isin(['50km','50mi']) ]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Combine all the filters together

# %%
df3 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df3.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df3.shape
# Out:
# (26090, 13)

# %%
#Remove (USA) from event name

# %%
df3['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df3['Event name'] = df3['Event name'].str.split('(').str.get(0)
# Out:
# /var/folders/cp/64j87vx54fv6vr30wbh6p31r0000gn/T/ipykernel_326/3354445535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Event name'] = df3['Event name'].str.split('(').str.get(0)

# %%
df3.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
#Clean up Athlete page

# %%
df3['athlete_age']= 2020- df3['Athlete year of birth']

# %%
#Remove h from athlete performance

# %%
df3['Athlete performance'] = df3['Athlete performance'].str.split(' ').str.get(0)

# %%
df3.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2539945                         20             3:17:55              M
# 2539946                         20             4:02:32              M
# 2539947                         20             4:07:57              M
# ...

# %%
#Drop columns: Athletes Club, Athlete Country, Athlete Year of Birth, Athlete Age Category

# %%
df3 = df3.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis=1)

# %%
#Clean up null values

# %%
df3.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete_age                  0
# dtype: int64

# %%
df3[df3['athlete_age'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
df3 = df3.dropna()

# %%
df3.shape
# Out:
# (22834, 10)

# %%
df3[df3.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
#Reset Index

# %%
df3.reset_index(drop=True)
# Out:
#        Year of event Event dates  \
# 0               2020  02.02.2020
# 1               2020  02.02.2020
# 2               2020  02.02.2020
# 3               2020  02.02.2020
# 4               2020  02.02.2020
# ...              ...         ...
# 22829           2020  03.10.2020
# 22830           2020  03.10.2020
# 22831           2020  03.10.2020
# 22832           2020  03.10.2020
# 22833           2020  03.10.2020
#
#                                           Event name Event distance/length  \
# 0      West Seattle Beach Run - Winter Edition (USA)                  50km
# 1      West Seattle Beach Run - Winter Edition (USA)                  50km
# 2      West Seattle Beach Run - Winter Edition (USA)                  50km
# 3      West Seattle Beach Run - Winter Edition (USA)                  50km
# 4      West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                              ...                   ...
# ...

# %%
#Fix Types

# %%
df3.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df3['athlete_age'] = df3['athlete_age'].astype(int)

# %%
df3['Athlete average speed'] = df3['Athlete average speed'].astype(float)

# %%
df3.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %%
df3.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2539945                         20             3:17:55              M
# 2539946                         20             4:02:32              M
# 2539947                         20             4:07:57              M
# ...

# %%
#Rename columns

# %%
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64


##Do not leave spaces when calling the column names because they will not be changed

# %%
df3 = df3.rename(columns = {'Year of event':'year',
                           'Event dates':'race_day',
                           'Event name':'race_name',
                           'Event distance/length':'race_length',
                           'Event number of finishers':'race_number_of_finishers',
                           'Athlete performance': 'athlete_performance',
                           'Athlete gender': 'athlete_gender',
                           'Athlete average speed': 'athlete_average_speed',
                           'Athlete ID': 'athlete_id'})

# %%
df3.head()
# Out:
#          year    race_day                                      race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race_number_of_finishers athlete_performance  \
# 2539945        50km                        20             3:17:55
# 2539946        50km                        20             4:02:32
# 2539947        50km                        20             4:07:57
# 2539948        50km                        20             4:22:02
# 2539949        50km                        20             4:27:34
#
#         athlete_gender  athlete_average_speed  athlete_id  athlete_age
# ...

# %%
#Reorder columns

# %%
df4 = df3[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','athlete_gender','athlete_age','athlete_performance','athlete_average_speed']]

# %%
df4.head()
# Out:
#            race_day                                      race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race_number_of_finishers  athlete_id athlete_gender  \
# 2539945        50km                        20       71287              M
# 2539946        50km                        20      629508              M
# 2539947        50km                        20       64838              M
# 2539948        50km                        20      704450              M
# 2539949        50km                        20      810281              M
#
#          athlete_age athlete_performance  athlete_average_speed
# ...

# %%
#Find 2 races

# %%
df4[df4['race_name'] == 'Everglades 50 Mile Ultra Run (USA)']
# Out:
#            race_day                           race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# ...

# %%
#222509-Ryan

# %%
df4[df4['athlete_id'] == 222509]
# Out:
#            race_day                           race_name race_length  \
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2591482                        40      222509              M           23
#
#         athlete_performance  athlete_average_speed
# 2591482             9:19:10                  8.634

# %%
#Charts and Graphs

# %%
sns.histplot(df4['race_length'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df4, x='race_length', hue='athlete_gender')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df4[df4['race_length'] == '50mi']['athlete_average_speed'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(data = df4, x='race_length', y='athlete_average_speed', hue='athlete_gender', split = True, inner = 'quart')
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df4, x='athlete_age', y= 'athlete_average_speed', hue = 'athlete_gender')

# %%
#Questions I want to find out from data

# %%
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64

# %%
#Different in speed for the 50k, 50mi male to female

# %%
df4.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.053849
#              M                 7.721989
# 50mi         F                 6.820359
#              M                 7.240810
# Name: athlete_average_speed, dtype: float64

# %%
#What age groups are the best in the 50m race (20 + races min)

# %%
df4.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False).query('count>19').head(15)
# Out:
#                  mean  count
# athlete_age
# 29           7.889707    123
# 23           7.698600     50
# 28           7.587792     96
# 30           7.529574    141
# 25           7.524000     79
# 38           7.452283    198
# 36           7.438932    162
# 31           7.390492    122
# 26           7.387836     73
# 42           7.380146    185
# 24           7.368435     69
# 35           7.348609    174
# 34           7.327699    166
# 21           7.315595     37
# 33           7.303633    128

# %%
#What age groups are the worst

# %%
df4.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = True).query('count>19').head(15)
# Out:
#                  mean  count
# athlete_age
# 60           6.031692     26
# 62           6.273438     32
# 61           6.289480     25
# 63           6.524500     30
# 58           6.604298     57
# 59           6.609589     73
# 50           6.633587    150
# 57           6.642727     66
# 53           6.684775     89
# 56           6.703678     59
# 52           6.725713    108
# 48           6.754140    114
# 49           6.809021    142
# 43           6.816789    166
# 54           6.850232     69

# %%
#Seasons for the data -> Slower in the summer than winter?

#Spring 3-5
#Summer 6-8
#Fall 9-11
#Winter 12-2

#Split between two decimals

# %%
df4['race_month'] = df4['race_day'].str.split('.').str.get(1).astype(int)

# %%
df4['race_season']= df4['race_month'].apply(lambda x: 'Winter' if x >11 else 'Fall' if x> 8 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter')

# %%
df4.tail()
# Out:
#            race_day                                     race_name race_length  \
# 2760956  03.10.2020  Yankee Springs Fall Trail Run Festival (USA)        50km
# 2760957  03.10.2020  Yankee Springs Fall Trail Run Festival (USA)        50km
# 2760958  03.10.2020  Yankee Springs Fall Trail Run Festival (USA)        50km
# 2760959  03.10.2020  Yankee Springs Fall Trail Run Festival (USA)        50km
# 2760960  03.10.2020  Yankee Springs Fall Trail Run Festival (USA)        50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2760956                        30      860348              M           49
# 2760957                        30      816361              F           62
# 2760958                        30      326469              F           43
# 2760959                        30      372174              F           58
# 2760960                        30      860349              F           39
#
# ...

# %%
df4.groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Spring       7.608495   3078
# Winter       7.524490   9934
# Fall         7.403170   7389
# Summer       6.806785   2433

# %%
#50 miler only

# %%
df4.query('race_length == "50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Fall         7.542307   1836
# Spring       7.084466    831
# Winter       6.990570   1553
# Summer       6.434160    758
